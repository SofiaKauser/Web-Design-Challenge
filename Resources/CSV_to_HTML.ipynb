# %%
# Importing Dependencies 
import pandas as pd

# %%
# Variable to store the 'cities' csv from the resources folder
cities = "Resources/cities.csv"

# %%
# Variable to read the csv and displaying the top 5 rows
read_cities = pd.read_csv(cities)
read_cities.head(5)

# %%
# Variable to store the converted csv in html format
cities_to_html = read_cities.to_html()
cities_to_html

# %%
# Removing the '\n' in each element 
cities_to_html.replace('\n', '')

# %%
# Converting and outputing the 'read_cities' data to html then calling it 'table' 
read_cities.to_html('table.html')
